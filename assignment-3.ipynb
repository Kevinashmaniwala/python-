# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('movies.csv')
data
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
data.head(10)
# Out:
#                                  Film      Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                     Youth in Revolt     Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                        When in Rome     Comedy                 Disney
# 4               What Happens in Vegas     Comedy                    Fox
# 5                 Water For Elephants      Drama       20th Century Fox
# 6                              WALL-E  Animation                 Disney
# 7                            Waitress    Romance            Independent
# 8                 Waiting For Forever    Romance            Independent
# 9                     Valentine's Day     Comedy           Warner Bros.
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# ...

# %%
a=data['Audience score %'].min(),data['Audience score %'].max()
a
# Out:
# (35, 89)

# %%
a=data.describe()
a
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         77.000000      77.000000          77.000000    77.000000
# mean          63.727273       4.599483          46.701299  2009.077922
# std           13.657113       8.031990          26.095001     1.354974
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.751351          26.000000  2008.000000
# 50%           64.000000       2.642353          45.000000  2009.000000
# 75%           76.000000       5.103117          64.000000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %%
x=data[['Film','Genre','Lead Studio','Year','Profitability','Rotten Tomatoes %','Worldwide Gross']]
y=data['Audience score %']
x,y
# Out:
# (                                  Film    Genre            Lead Studio  Year  \
#  0           Zack and Miri Make a Porno  Romance  The Weinstein Company  2008
#  1                      Youth in Revolt   Comedy  The Weinstein Company  2010
#  2   You Will Meet a Tall Dark Stranger   Comedy            Independent  2010
#  3                         When in Rome   Comedy                 Disney  2010
#  4                What Happens in Vegas   Comedy                    Fox  2008
#  ..                                 ...      ...                    ...   ...
#  72                 Across the Universe  romance            Independent  2007
#  73                       A Serious Man    Drama              Universal  2009
#  74                  A Dangerous Method    Drama            Independent  2011
#  75                          27 Dresses   Comedy                    Fox  2008
#  76                (500) Days of Summer   comedy                    Fox  2009
#
# ...

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.30)
x_test,y_test,x_train,y_train
# Out:
# (                                   Film      Genre            Lead Studio  \
#  51                       License to Wed     Comedy           Warner Bros.
#  35                    Not Easily Broken      Drama            Independent
#  1                       Youth in Revolt     Comedy  The Weinstein Company
#  29               Rachel Getting Married      Drama            Independent
#  75                           27 Dresses     Comedy                    Fox
#  25                 Sex and the City Two     Comedy           Warner Bros.
#  63                   Going the Distance     Comedy           Warner Bros.
#  61          He's Just Not That Into You     Comedy           Warner Bros.
#  36                      No Reservations     Comedy           Warner Bros.
#  53                            Leap Year     Comedy              Universal
#  21                     The Back-up Plan     Comedy                    CBS
# ...

# %%
#set-3

# %%
data.tail(10)
# Out:
#                     Film    Genre   Lead Studio  Audience score %  \
# 67      Four Christmases   Comedy  Warner Bros.                52
# 68             Fireproof    Drama   Independent                51
# 69             Enchanted   Comedy        Disney                80
# 70             Dear John    Drama          Sony                66
# 71             Beginners   Comedy   Independent                80
# 72   Across the Universe  romance   Independent                84
# 73         A Serious Man    Drama     Universal                64
# 74    A Dangerous Method    Drama   Independent                89
# 75            27 Dresses   Comedy           Fox                71
# 76  (500) Days of Summer   comedy           Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 67       2.022925                 26        $161.83   2008
# 68      66.934000                 40         $33.47   2008
# 69       4.005737                 93        $340.49   2007
# ...

# %%
data.dropna()
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
data.describe()
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         77.000000      77.000000          77.000000    77.000000
# mean          63.727273       4.599483          46.701299  2009.077922
# std           13.657113       8.031990          26.095001     1.354974
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.751351          26.000000  2008.000000
# 50%           64.000000       2.642353          45.000000  2009.000000
# 75%           76.000000       5.103117          64.000000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %%
x=data[['Film','Genre','Lead Studio','Year','Profitability','Rotten Tomatoes %','Worldwide Gross']]
y=data['Audience score %']
x,y
# Out:
# (                                  Film    Genre            Lead Studio  Year  \
#  0           Zack and Miri Make a Porno  Romance  The Weinstein Company  2008
#  1                      Youth in Revolt   Comedy  The Weinstein Company  2010
#  2   You Will Meet a Tall Dark Stranger   Comedy            Independent  2010
#  3                         When in Rome   Comedy                 Disney  2010
#  4                What Happens in Vegas   Comedy                    Fox  2008
#  ..                                 ...      ...                    ...   ...
#  72                 Across the Universe  romance            Independent  2007
#  73                       A Serious Man    Drama              Universal  2009
#  74                  A Dangerous Method    Drama            Independent  2011
#  75                          27 Dresses   Comedy                    Fox  2008
#  76                (500) Days of Summer   comedy                    Fox  2009
#
# ...

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.25)
x_test,y_test,x_train,y_train
# Out:
# (                                   Film      Genre            Lead Studio  \
#  40                     Music and Lyrics    Romance           Warner Bros.
#  0            Zack and Miri Make a Porno    Romance  The Weinstein Company
#  58                     It's Complicated     Comedy              Universal
#  4                 What Happens in Vegas     Comedy                    Fox
#  38                       New Year's Eve    Romance           Warner Bros.
#  61          He's Just Not That Into You     Comedy           Warner Bros.
#  15             The Time Traveler's Wife      Drama              Paramount
#  43                    Midnight in Paris    Romence                   Sony
#  3                          When in Rome     Comedy                 Disney
#  35                    Not Easily Broken      Drama            Independent
#  76                 (500) Days of Summer     comedy                    Fox
# ...

# %%
#set-2
